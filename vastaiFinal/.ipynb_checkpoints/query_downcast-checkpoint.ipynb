# %%
import os
import json
import time
import requests
import pandas as pd
import numpy as np
from datetime import datetime, date, timedelta as _td
from google.auth import aws
from google.cloud import bigquery
from google.api_core import exceptions as gcp_exc

# %%
IMDS = "http://169.254.169.254/latest"

def _imds_token():
    return requests.put(
        f"{IMDS}/api/token",
        headers={"X-aws-ec2-metadata-token-ttl-seconds": "21600"},
        timeout=2,
    ).text

class IMDSv2Supplier(aws.AwsSecurityCredentialsSupplier):
    def get_aws_region(self, context, request):
        az = requests.get(
            f"{IMDS}/meta-data/placement/availability-zone",
            headers={"X-aws-ec2-metadata-token": _imds_token()},
            timeout=2,
        ).text
        return az[:-1]

    def get_aws_security_credentials(self, context, request):
        tok = _imds_token()
        role = requests.get(
            f"{IMDS}/meta-data/iam/security-credentials/",
            headers={"X-aws-ec2-metadata-token": tok},
            timeout=2,
        ).text.strip()
        creds = json.loads(requests.get(
            f"{IMDS}/meta-data/iam/security-credentials/{role}",
            headers={"X-aws-ec2-metadata-token": tok},
            timeout=2,
        ).text)
        return aws.AwsSecurityCredentials(
            access_key_id=creds["AccessKeyId"],
            secret_access_key=creds["SecretAccessKey"],
            session_token=creds.get("Token"),
        )

with open("/home/ubuntu/project/final_credentials.json") as f:
    info = json.load(f)

credentials = aws.Credentials(
    audience=info["audience"],
    subject_token_type=info["subject_token_type"],
    token_url=info["token_url"],
    service_account_impersonation_url=info["service_account_impersonation_url"],
    aws_security_credentials_supplier=IMDSv2Supplier(),
)

client = bigquery.Client(project="analog-subset-491623-j7", credentials=credentials)

query = "SELECT 'Handshake Successful!' as status"
for row in client.query(query):
    print(row.status)
# Out:
# Handshake Successful!

# %%
# Flash Loan Cascade: Deep Sequence Detection
# Goal: Detect complex multi-protocol arbitrage and exploit chains using "No-Join" account arrays.
# Ideal for: Transformer AE "Feature-Attention" and Sequence Profiling.
# ── UPDATED CONFIGURATION FOR CASCADES ────────────────────────────
DATASET_ID = 'my_dataset_uc_4'
# Daily chunks: one feather file per day across 5 months
_d, _end = date(2024, 9, 1), date(2025, 1, 31)
chunks = []
while _d <= _end:
    _s = _d.strftime('%Y-%m-%d')
    chunks.append((_s, _s))
    _d += _td(days=1)
names = [c[0] for c in chunks]
# Removed deprecated features from array to match the new SQL query exactly.
EXPECTED_FEATURE_COLUMNS = [
    # Base Transaction Data
    'signature', 'block_timestamp', 'tx_date', 'wallet', 'fee_sol', 'compute_units_consumed',
    'success_flag', 'num_accounts', 'log_count', 'num_balance_changes', 'max_sol_change',

    # Protocol Hop Features
    'dex_hop_count', 'debt_hop_count', 'unique_nonsigner_account_count',

    # Execution Structure
    'involves_sysvar_flag', 'max_cpi_depth', 'inner_instruction_count', 'unique_program_count',

    # Value Extraction
    'instigator_net_token_profit', 'instigator_sol_delta', 'instigator_fiat_delta',
    'mint_diversity',
]
# This defines the numeric subset passed into the Transformer/Scaler
# Engineered features (hop_density, avg_depth_per_protocol, unknown_program_count,
# has_fiat_profit, has_token_profit, has_sol_profit) are added by preprocess.engineer_features()
# at training time -- not present in raw feather files.
tx_feature_cols = [
    'fee_sol', 'compute_units_consumed', 'num_accounts', 'log_count',
    'num_balance_changes', 'max_sol_change', 'dex_hop_count', 'debt_hop_count',
    'unique_nonsigner_account_count',
    'involves_sysvar_flag', 'max_cpi_depth', 'inner_instruction_count',
    'instigator_net_token_profit', 'instigator_sol_delta', 'instigator_fiat_delta',
    'mint_diversity',
]
# ──────────────────────────────────────────────────────────────────

# %%
def get_cascade_query(dataset_id, start_date, end_date, daily_cap=None):
    limit_clause = f"ORDER BY block_timestamp, signature LIMIT {daily_cap}" if daily_cap else ""
    return f"""
CREATE OR REPLACE TABLE {dataset_id}.flash_loan_cascade_features
PARTITION BY tx_date
CLUSTER BY wallet
AS
WITH raw_base AS (
  SELECT
    signature,
    block_timestamp,
    DATE(block_timestamp) AS tx_date,
    fee / 1e9 AS fee_sol,
    compute_units_consumed,
    IF(status='Success',1,0) AS success_flag,
    
    -- IDENTIFY PRIMARY ACTOR (Excludes infrastructure & keeper bots)
    (SELECT a.pubkey FROM UNNEST(accounts) a WITH OFFSET pos
     WHERE a.signer 
       AND a.pubkey NOT IN (
          -- System / Infrastructure
          '11111111111111111111111111111111',            -- System Program
          'ComputeBudget111111111111111111111111111111', -- Compute Budget Program
          -- DEX / AMMs
          'JUP6LkbZbjS1jKKwapdHNy74zcZ3tLUZoi5QNyVTaV4', -- Jupiter v6 Aggregator
          'jupPAzUY5Ncvrwp3WbagoQL3wr2gJnK9KWwVMFjgCMm', -- Jupiter v3 Aggregator
          '675kPX9MHTjS2zt1qfr1NYHuzeLXfQM9H24wFSUt1Mp8', -- Raydium AMM v4
          'whirLuv3caEkYvHWfCHsrTfcTGSW7uRckyAm7pKA5MC', -- Orca Whirlpool
          '6EF8rrecthR5Dkzon8Nwu78hRvfCKubJ14M5uBEwF6P', -- Pump.fun
          'LBUZKhR7JkaNmMbhxuCc3C6rSkmcz6ZXLMa7YjtAn2D', -- Meteora DLMM
          'PhoeNiXZ8ByJGLkxNfZRnkUfjvmuYqLR89jjFHGqdXY', -- Phoenix DEX
          '2wT8Yq49kHgDzXuPxZSaeLaH1qbmGXtEyPy64bL7aD3c', -- Lifinity V2
          '9xQeWvG816bUx9EPjHmaT23yvVM2ZWbrrpZb9PusVFin', -- Serum DEX v3 / OpenBook
          'SSwpkEEcbUqx4vtoEByFjSkhKdCT862DNVb52nZg1UZ', -- Saber Stable AMM
          -- Lending / Perps
          '6LtLpnUFNByNXLyCoK9wA2MykKAmQNZKBdY8s47dehDc', -- Kamino Finance
          'So1endDq2YkqTCqM3vYpe61CPLUD6nHRN4um8HEufXq', -- Solend
          'MFv2hWf31Z9kbCa1snEPYpcwiNcNVt7BvR9LpXkXVwN', -- MarginFi
          'dRiftyHA39MWEi3m9aunc5MzRF1JYuBsEX6TUqavNbc', -- Drift Protocol
          '4MangoMjqJ2firMokCjjGgoK8d4MXcrgL7XJaL3w6fVg', -- Mango Markets V4
          'mv3ekLzLbnVPNxjZApeBp42ewPtzy6H8N15Kq6n2Y1z', -- Mango Markets V3
          'ZETAxsqBRek56DhiGXrn75yj2NHU3aYUnxvHXpkf3aD'  -- Zeta Markets
       ) 
     ORDER BY pos ASC
     LIMIT 1) AS wallet,
     
    accounts,
    log_messages,
    pre_token_balances,
    post_token_balances,
    balance_changes
  FROM `bigquery-public-data.crypto_solana_mainnet_us.Transactions`
  WHERE block_timestamp >= TIMESTAMP('{start_date}') AND block_timestamp < TIMESTAMP_ADD(TIMESTAMP('{end_date}'), INTERVAL 1 DAY)
    AND status = 'Success'
    -- TRIGGER: Focus on complex transactions
    AND (compute_units_consumed > 500000 OR ARRAY_LENGTH(log_messages) > 30)
),
stratified_sample AS (
  -- WALLET-LEVEL STRATIFIED SAMPLING: Keep 10% of unique wallets
  SELECT * FROM raw_base
  WHERE MOD(ABS(FARM_FINGERPRINT(wallet)), 10) = 0
)
SELECT
    signature,
    block_timestamp,
    tx_date,
    wallet,
    fee_sol,
    compute_units_consumed,
    success_flag,
    -- 1. THE FLASH LOAN SIGNAL (Instructions Sysvar)
    (SELECT IF(COUNT(1) > 0, 1, 0) FROM UNNEST(accounts) a 
     WHERE a.pubkey = 'Sysvar1nstructions1111111111111111111111111') AS involves_sysvar_flag,
    -- 2. CASCADE LOGIC (Depth & Count)
    (SELECT MAX(CAST(REGEXP_EXTRACT(msg, r'invoke \\[(\\d+)\\]') AS INT64)) FROM UNNEST(log_messages) msg) AS max_cpi_depth,
    (SELECT COUNTIF(REGEXP_CONTAINS(msg, r'Program .* invoke')) FROM UNNEST(log_messages) msg) AS inner_instruction_count,
    -- 3a. DEX TRANSIT COUNT (Aggregators / AMMs)
    (SELECT COUNT(DISTINCT a.pubkey) FROM UNNEST(accounts) a 
     WHERE a.pubkey IN (
        'JUP6LkbZbjS1jKKwapdHNy74zcZ3tLUZoi5QNyVTaV4', -- Jupiter
        '675kPX9MHTjS2zt1qfr1NYHuzeLXfQM9H24wFSUt1Mp8', -- Raydium
        'whirLuv3caEkYvHWfCHsrTfcTGSW7uRckyAm7pKA5MC', -- Orca Whirlpool
        '6EF8rrecthR5Dkzon8Nwu78hRvfCKubJ14M5uBEwF6P', -- Pump.fun
        'LBUZKhR7JkaNmMbhxuCc3C6rSkmcz6ZXLMa7YjtAn2D', -- Meteora
        'PhoeNiXZ8ByJGLkxNfZRnkUfjvmuYqLR89jjFHGqdXY', -- Phoenix
        '2wT8Yq49kHgDzXuPxZSaeLaH1qbmGXtEyPy64bL7aD3c', -- Lifinity V2
        '9xQeWvG816bUx9EPjHmaT23yvVM2ZWbrrpZb9PusVFin', -- Serum DEX v3 / OpenBook
        'SSwpkEEcbUqx4vtoEByFjSkhKdCT862DNVb52nZg1UZ'  -- Saber
     )
    ) AS dex_hop_count,
    -- 3b. DEBT HUB COUNT (Lending / Perps)
    (SELECT COUNT(DISTINCT a.pubkey) FROM UNNEST(accounts) a 
     WHERE a.pubkey IN (
        '6LtLpnUFNByNXLyCoK9wA2MykKAmQNZKBdY8s47dehDc', -- Kamino
        'So1endDq2YkqTCqM3vYpe61CPLUD6nHRN4um8HEufXq', -- Solend
        'MFv2hWf31Z9kbCa1snEPYpcwiNcNVt7BvR9LpXkXVwN', -- MarginFi
        'dRiftyHA39MWEi3m9aunc5MzRF1JYuBsEX6TUqavNbc', -- Drift
        '4MangoMjqJ2firMokCjjGgoK8d4MXcrgL7XJaL3w6fVg', -- Mango V4
        'mv3ekLzLbnVPNxjZApeBp42ewPtzy6H8N15Kq6n2Y1z', -- Mango V3
        'ZETAxsqBRek56DhiGXrn75yj2NHU3aYUnxvHXpkf3aD'  -- Zeta
     )
    ) AS debt_hop_count,
    -- 4. FINANCIAL IMPACT (Max Token Extraction in Transaction)
    -- MAX across all accounts (not instigator-only): profits route through PDAs.
    -- MAX not SUM: avoids cross-token unit mismatch. NULLs (SOL-only txns) -> 0 in preprocessing.
    (SELECT MAX(SAFE_DIVIDE(CAST(post.amount AS FLOAT64) - CAST(pre.amount AS FLOAT64), POW(10, CAST(pre.decimals AS INT64))))
     FROM UNNEST(post_token_balances) post
     INNER JOIN UNNEST(pre_token_balances) pre ON post.account_index = pre.account_index AND post.mint = pre.mint
     WHERE CAST(post.amount AS FLOAT64) > CAST(pre.amount AS FLOAT64)
    ) AS instigator_net_token_profit,
    -- 4b. VALUE EXTRACTION TRIAD
    -- SOL delta: positive = bot gained SOL (native asset / gas)
    COALESCE((
      SELECT (bc.after - bc.before)
      FROM UNNEST(balance_changes) bc
      WHERE bc.account = wallet
      LIMIT 1
    ), 0) / 1e9 AS instigator_sol_delta,
    -- Fiat delta: net fiat-pegged stablecoin flow to instigator wallet
    -- Covers USDC + USDT + PYUSD + USDG: transactional stablecoins present in DeFi lending pools
    COALESCE((
      SELECT SUM(SAFE_DIVIDE(
        CAST(post.amount AS FLOAT64) - CAST(pre.amount AS FLOAT64),
        POW(10, CAST(pre.decimals AS INT64))
      ))
      FROM UNNEST(post_token_balances) post
      INNER JOIN UNNEST(pre_token_balances) pre ON post.account_index = pre.account_index AND post.mint = pre.mint
      WHERE post.owner = wallet
        AND post.mint IN (
          'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v', -- USDC
          'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB', -- USDT
          '2b1kV6DkPAnxd5ixfnxCpjxmKwqjjaYmCZfHsFu24GXo', -- PYUSD (PayPal USD)
          '2u1tszSeqZ3qBWF3uNGPFc8TzMk2tdiwknnRMWGWjGWH'  -- USDG (Global Dollar, Paxos)
        )
    ), 0) AS instigator_fiat_delta,
    -- 5. STRUCTURAL GENERIC FEATURES
    (SELECT COUNT(DISTINCT a.pubkey) FROM UNNEST(accounts) a 
     WHERE a.pubkey NOT IN ('TokenkegQfeZyiNwAJbNbGKPFXCWuBvf9Ss623VQ5DA','11111111111111111111111111111111','ComputeBudget111111111111111111111111111111')
     AND NOT a.signer) AS unique_nonsigner_account_count,
    ARRAY_LENGTH(log_messages) AS log_count,
    ARRAY_LENGTH(accounts) AS num_accounts,
    ARRAY_LENGTH(balance_changes) AS num_balance_changes,
    COALESCE((SELECT MAX(ABS(bc.after - bc.before)) FROM UNNEST(balance_changes) bc), 0)/1e9 AS max_sol_change,
    (SELECT COUNT(DISTINCT tb.mint) FROM UNNEST(pre_token_balances) tb) AS mint_diversity,
    -- 6. PURE COMPOSABILITY: actual unique smart contracts invoked
    -- Parsed from runtime logs: every program call emits 'Program <ADDR> invoke [N]'
    -- Counts known + unknown protocols -- the definitive composability signal
    (SELECT COUNT(DISTINCT REGEXP_EXTRACT(msg, r'Program (\\S+) invoke'))
     FROM UNNEST(log_messages) msg
     WHERE REGEXP_CONTAINS(msg, r'Program \\S+ invoke')
    ) AS unique_program_count
FROM (
    SELECT * FROM stratified_sample
    WHERE wallet IS NOT NULL
    {limit_clause}
)
"""

# %%
def downcast_df(df):
    """Reduce RAM usage by downcasting numeric types."""
    fcols = df.select_dtypes('float').columns
    icols = df.select_dtypes('integer').columns
    df[fcols] = df[fcols].apply(pd.to_numeric, downcast='float')
    df[icols] = df[icols].apply(pd.to_numeric, downcast='integer')
    return df

# %%
# Assuming client is instantiated elsewhere in your real script
# client = bigquery.Client()

def run_validation(client):
    # ---- Pre-live validation + optional live run ----

    # Step 0: ensure dataset exists in us-central1
    dataset_ref = bigquery.DatasetReference(client.project, DATASET_ID)
    dataset = bigquery.Dataset(dataset_ref)
    dataset.location = 'us-central1'
    try:
        client.create_dataset(dataset, exists_ok=True)
        print('Dataset ready.')
    except gcp_exc.Forbidden:
        try:
            client.get_dataset(dataset_ref)
            print('Dataset already exists - continuing.')
        except Exception as exc:
            raise RuntimeError(
                f"Dataset '{DATASET_ID}' missing and service account cannot create it. "
                "Create it manually with location us-central1."
            ) from exc
    except gcp_exc.Conflict:
         print('Dataset already exists - continuing.')

    # Step 1: probe source table access
    print("\nProbing access to public Solana transactions table...")
    probe_sql = """
        SELECT COUNT(*) AS n
        FROM `bigquery-public-data.crypto_solana_mainnet_us.Transactions`
        WHERE block_timestamp BETWEEN '2024-09-01' AND '2024-09-01 00:01:00'
    """
    probe_job = client.query(probe_sql, location='us-central1')
    probe = probe_job.result()
    count = next(iter(probe))['n']
    print(f"  Access confirmed - {count:,} rows in first minute of 2024-09-01 (Job ID: {probe_job.job_id})\n")

    # Step 1.5: feature-level sample validation
    print('Running feature-level sample check before live run...')
    sample_start = '2024-09-01'
    sample_end = '2024-09-01'

    # The new query is a single, triggered CTE pipeline, not a two-step random sampler.
    # Therefore, 'presample_pct' is removed. We just increase the daily_cap limit.
    attempts = [
        {'daily_cap': 20},
        {'daily_cap': 100},
        {'daily_cap': 300},
    ]

    sample_q = f"""
        SELECT *
        FROM {DATASET_ID}.flash_loan_cascade_features
        WHERE tx_date BETWEEN DATE('{sample_start}') AND DATE('{sample_end}')
        ORDER BY block_timestamp, signature
        LIMIT 10
    """

    sample_df = None
    for i, cfg in enumerate(attempts, start=1):
        print(
            f"  Sample attempt {i}/{len(attempts)} "
            f"(daily_cap={cfg['daily_cap']})..."
        )
        
        # Execute the new single-stage Cascade query directly
        build_job = client.query(
            get_cascade_query(
                DATASET_ID,
                sample_start,
                sample_end,
                daily_cap=cfg['daily_cap']
            ),
            location='us-central1',
        )
        build_job.result()
        print(f"    -> Build Job ID: {build_job.job_id}")
        
        extract_job = client.query(sample_q, location='us-central1')
        sample_df = extract_job.to_dataframe()
        print(f"    -> Extract Job ID: {extract_job.job_id}")
        if not sample_df.empty:
            break

    if sample_df is None or sample_df.empty:
        raise RuntimeError(
            'Feature sample query returned 0 rows. '
            'This means no transactions met the Cascade trigger condition (Compute > 500k & 2+ Protocols) on this date. '
            'Try widening sample dates.'
        )

    print("\n--- Raw Data Validation ---")
    print(f"Raw rows: {len(sample_df)}")
    null_counts = sample_df.isnull().sum()
    if null_counts.sum() > 0:
        print("Null counts per column (Raw):")
        print(null_counts[null_counts > 0].to_string())
    else:
        print("No nulls found in raw data.")
    print("---------------------------\n")

    # Apply dtype compression (same as live run), then engineer features for preview
    sample_df = downcast_df(sample_df)
    #sample_df = preprocess.engineer_features(sample_df)

    print(f"Feature sample returned {len(sample_df)} rows.")
    print(f"Feature column count (after engineering): {len(sample_df.columns)}")
    print('BQ columns:')
    print(', '.join(EXPECTED_FEATURE_COLUMNS))

    missing = [c for c in EXPECTED_FEATURE_COLUMNS if c not in sample_df.columns]
    if missing:
        raise RuntimeError('Feature schema mismatch. Missing expected columns: ' + ', '.join(missing))

    print('Schema check passed: all expected feature columns are present.')
    print('\nPreview row:')
    print(sample_df.head(1).to_string(index=False))
    print('\n' + '=' * 65 + '\n')
    
    key_cols = [
      'wallet', 'fee_sol',
      'instigator_sol_delta', 'instigator_fiat_delta', 'instigator_net_token_profit',
      'dex_hop_count', 'debt_hop_count', 'unique_program_count',
      'max_cpi_depth', 'inner_instruction_count',
      'max_sol_change', 'mint_diversity',
    ]                                                                                                                                    
    pd.set_option('display.max_columns', None)                                                                                                        
    pd.set_option('display.width', 300)
    pd.set_option('display.float_format', '{:.6f}'.format)
    print('\nFull sample (all 10 rows):')                                                                                                             
    print(sample_df[key_cols].to_string(index=False))

if __name__ == '__main__':
    client = bigquery.Client(project="analog-subset-491623-j7", credentials=credentials)
    run_validation(client)
# Out:
# Dataset ready.
#
# Probing access to public Solana transactions table...
#   Access confirmed - 209,592 rows in first minute of 2024-09-01 (Job ID: 18ab53e0-7b62-4318-9438-cabdd1577117)
#
# Running feature-level sample check before live run...
#   Sample attempt 1/3 (daily_cap=20)...
#     -> Build Job ID: 58b6314a-b964-4c57-a6a0-0a017b7bea81
#     -> Extract Job ID: 83ead1a7-c86b-4f77-b687-af4d4db1aa9f
#
# --- Raw Data Validation ---
# Raw rows: 10
# Null counts per column (Raw):
# instigator_net_token_profit    2
# ---------------------------
#
# Feature sample returned 10 rows.
# Feature column count (after engineering): 22
# BQ columns:
# signature, block_timestamp, tx_date, wallet, fee_sol, compute_units_consumed, success_flag, num_accounts, log_count, num_balance_changes, max_sol_change, dex_hop_count, debt_hop_count, unique_nonsigner_account_count, involves_sysvar_flag, max_cpi_depth, inner_instruction_count, unique_program_count, instigator_net_token_profit, instigator_sol_delta, instigator_fiat_delta, mint_diversity
# Schema check passed: all expected feature columns are present.
#
# Preview row:
#                                                                                signature           block_timestamp    tx_date                                       wallet     fee_sol compute_units_consumed  success_flag  involves_sysvar_flag  max_cpi_depth  inner_instruction_count  dex_hop_count  debt_hop_count  instigator_net_token_profit instigator_sol_delta  instigator_fiat_delta  unique_nonsigner_account_count  log_count  num_accounts  num_balance_changes max_sol_change  mint_diversity  unique_program_count
# 2HmracCzUnFnVLapp3aDqXYLYH3ymee1q9kSzBzNnm9bGWXAxXMt7iBxNoLj2RU7o36SZ2JhE311NQ8Ju7M2ujNj 2024-09-01 00:00:00+00:00 2024-09-01 HtLhHRLNZb666bJFDXRa12A1u2G51kkt5bTVWwaswaC6 0.000010000        66590.000000000             1                     0              2                       14              1               0                     0.101810         -0.001000000               0.000000                              21         53            25                   25    0.001000000               2                     4
#
# =================================================================
#
#
# Full sample (all 10 rows):
#                                       wallet     fee_sol instigator_sol_delta  instigator_fiat_delta  instigator_net_token_profit  dex_hop_count  debt_hop_count  unique_program_count  max_cpi_depth  inner_instruction_count max_sol_change  mint_diversity
# HtLhHRLNZb666bJFDXRa12A1u2G51kkt5bTVWwaswaC6 0.000010000         -0.001000000               0.000000                     0.101810              1               0                     4              2                       14    0.001000000               2
# 5amu6s7vnxDLfUvsUrL4FaQpgi62jmn7ut275csbyy6k 0.000011545         -0.000011545               0.000000                     2.579313              1               0                     5              2                       15    0.000011545               2
# 7UDGvpgG6Y7J88d3wEqUNTg7QdPdMFtYSXqSUXtvqcpr 0.000011545         -0.000011545               0.000000                    15.956598              1               0                     5              2                       15    0.000011545               2
# E47nZoTvG2B58X7jJRXCmxUQFgyUguivRRbfNfytCrfg 0.000011545         -0.000011545               0.000000                   103.199174              1               0                     5              2                       15    0.000011545               2
# 8BvjyzhgK45GHthJUfvEoF8KVHwpWzp9woPVHtFgF865 0.000010000         -0.000010000               0.000000                 53567.243498              1               0                     4              2                       17    0.130039280               2
# 26xGQKtRhaxbQ9k78EV1DCtaqpCmr5y2tB5Gt5zNFCMh 0.000015501          0.040587724               0.000000                 49041.846357              1               0                     6              3                       13    0.040603225               2
# 5ddo32xdfxBvxweFYeSDbteK53Fj68fAVvVqyRF6MpHY 0.000006375         -0.000006375               0.000000                          NaN              0               0                     2              1                        4    0.000006375               0
# AyeXddePQiYTYmwzMh1Eu8hVW2jiAqbuN6m6khVi3amx 0.000020232         -0.000020232               0.000000                496220.169302              1               0                     5              2                       11    0.347000000               2
# 5ddo32xdfxBvxweFYeSDbteK53Fj68fAVvVqyRF6MpHY 0.000006375         -0.000006375               0.000000                          NaN              0               0                     2              1                        4    0.000006375               0
# Fe9scrbU85UPMWsFmaKBddw5c52gvVwGL9zHA5V3irdo 0.000011545         -0.000011545               0.000000                     2.579313              1               0                     5              2                       15    0.000011545               2

# %%
RUN_LIVE = True  # Set to True when you want chunk export.
if RUN_LIVE:
    save_dir = '/mnt/project_chunks'
    os.makedirs(save_dir, exist_ok=True)
    for s_str, e_str in chunks:
        out_path = os.path.join(save_dir, f'{s_str}.feather')
        if os.path.exists(out_path):
            print(f'[{s_str}] Skip - exists')
            continue
        print(f'\n=== {s_str} ===')
        # 1. Build features for this day
        print('  [1/2] Engineering Cascade features...')
        job1 = client.query(get_cascade_query(DATASET_ID, s_str, e_str, daily_cap=None), location='us-central1')
        job1.result()
        # 2. Extract and downcast
        print('  [2/2] Exporting to feather...')
        q = f"""
            SELECT *
            FROM {DATASET_ID}.flash_loan_cascade_features
            WHERE tx_date = '{s_str}'
        """
        job2 = client.query(q, location='us-central1')
        df = job2.to_dataframe(progress_bar_type='tqdm')
        if not df.empty:
            df = downcast_df(df)
            df.to_feather(out_path)
        bytes_billed = (job1.total_bytes_billed or 0) + (job2.total_bytes_billed or 0)
        total_gb = bytes_billed / (1024**3)
        print(f'      Rows: {len(df):,}')
        print(f'      Data Scanned: {total_gb:.2f} GB')
        print(f'      Est. Cost: ${(total_gb/1024) * 5.0:.4f}')
        del df
        time.sleep(1)
    print('\nAll chunks complete.')
else:
    print('RUN_LIVE=False, so only pre-live validation was executed.')
# Out:
# === 2024-09-01 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 3d6e8cac-b527-4f66-824a-858c0d00ae9f successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 985,633
#       Data Scanned: 369.09 GB
#       Est. Cost: $1.8022
#
# === 2024-09-02 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 8d0817ec-a712-40c7-a23e-a3dbccab1341 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,167,295
#       Data Scanned: 398.47 GB
#       Est. Cost: $1.9457
#
# === 2024-09-03 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 663361a8-069c-4b55-a03f-9b6a0d05472c successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,148,710
#       Data Scanned: 400.13 GB
#       Est. Cost: $1.9538
#
# === 2024-09-04 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 8bcdde6e-83fb-41eb-b3db-7c5ade2c66d9 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,241,035
#       Data Scanned: 386.21 GB
#       Est. Cost: $1.8858
#
# === 2024-09-05 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID cd05f028-7ed2-41fa-aeb0-7c5888c04734 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,400,711
#       Data Scanned: 381.26 GB
#       Est. Cost: $1.8616
#
# === 2024-09-06 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 7ec51c09-d364-4f8e-9742-8167545a545b successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,468,852
#       Data Scanned: 368.32 GB
#       Est. Cost: $1.7985
#
# === 2024-09-07 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 3f6dd33f-5847-4dd5-849c-b7ae393944aa successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,246,237
#       Data Scanned: 368.06 GB
#       Est. Cost: $1.7972
#
# === 2024-09-08 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 29515a19-84bb-46c7-b4f5-698a35aa66ca successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,141,725
#       Data Scanned: 357.68 GB
#       Est. Cost: $1.7465
#
# === 2024-09-09 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 2faef265-9728-4c6a-8e79-0eaf3d236498 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,599,304
#       Data Scanned: 396.20 GB
#       Est. Cost: $1.9345
#
# === 2024-09-10 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID adfd90af-96a6-435a-be7d-267ebcc81ad9 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,525,093
#       Data Scanned: 384.41 GB
#       Est. Cost: $1.8770
#
# === 2024-09-11 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 70465b6c-877b-430a-a929-c46890f5a423 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,436,810
#       Data Scanned: 382.24 GB
#       Est. Cost: $1.8664
#
# === 2024-09-12 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID c38f23d4-bf97-413c-a579-6f60c5495cc8 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,458,366
#       Data Scanned: 386.61 GB
#       Est. Cost: $1.8878
#
# === 2024-09-13 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID dac83eb4-b112-411f-b6d6-34a03ae60443 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,225,407
#       Data Scanned: 345.88 GB
#       Est. Cost: $1.6889
#
# === 2024-09-14 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 29c7f71d-e733-4451-ab0d-f59342fa2a1a successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,409,202
#       Data Scanned: 380.15 GB
#       Est. Cost: $1.8562
#
# === 2024-09-15 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID c32544de-9d6a-41c5-8dff-7f0996d517a0 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,214,638
#       Data Scanned: 371.63 GB
#       Est. Cost: $1.8146
#
# === 2024-09-16 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID ebd98c47-f93a-4480-9f36-2299676287a0 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,305,089
#       Data Scanned: 373.21 GB
#       Est. Cost: $1.8223
#
# === 2024-09-17 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID e1de0ee0-b6ea-4fd4-b2c0-4b871fa49855 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,434,140
#       Data Scanned: 379.05 GB
#       Est. Cost: $1.8508
#
# === 2024-09-18 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 7fd1293e-1a87-4134-b321-7f3b0c1be29f successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,456,168
#       Data Scanned: 398.09 GB
#       Est. Cost: $1.9438
#
# === 2024-09-19 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 2f58adff-b4b0-44bb-b435-3b8e25fcadbb successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,517,493
#       Data Scanned: 391.50 GB
#       Est. Cost: $1.9116
#
# === 2024-09-20 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID f93d6b9b-6387-4bba-a1c5-4978253c9739 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,443,171
#       Data Scanned: 388.96 GB
#       Est. Cost: $1.8992
#
# === 2024-09-21 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID fe117ddf-635d-4ad5-8661-46c380aa6d5c successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,219,369
#       Data Scanned: 390.19 GB
#       Est. Cost: $1.9052
#
# === 2024-09-22 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 72d71185-e805-496a-97f9-2ad10f40f4db successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,500,423
#       Data Scanned: 395.05 GB
#       Est. Cost: $1.9289
#
# === 2024-09-23 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 5c6f0dbd-036e-4e69-89a9-f937eb07ab52 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,519,611
#       Data Scanned: 389.95 GB
#       Est. Cost: $1.9041
#
# === 2024-09-24 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 2b89208c-941a-4c6f-85d4-cb745879f5da successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,526,852
#       Data Scanned: 374.53 GB
#       Est. Cost: $1.8288
#
# === 2024-09-25 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 9c76348f-6708-49ae-a5d2-8e71c15844ae successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,504,404
#       Data Scanned: 343.01 GB
#       Est. Cost: $1.6749
#
# === 2024-09-26 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID fe23834a-2a0a-4118-99ef-1c84c5c1326d successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,829,730
#       Data Scanned: 368.83 GB
#       Est. Cost: $1.8009
#
# === 2024-09-27 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID e9f2ba31-9d43-49b3-8372-5e7abb7d0bc7 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,879,465
#       Data Scanned: 379.07 GB
#       Est. Cost: $1.8509
#
# === 2024-09-28 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID be0c1be8-8f40-4685-a8bb-1fb009665108 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,588,607
#       Data Scanned: 356.73 GB
#       Est. Cost: $1.7418
#
# === 2024-09-29 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID b17c4a0d-26bd-42fe-9d2e-9747bdb83029 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,668,608
#       Data Scanned: 402.58 GB
#       Est. Cost: $1.9657
#
# === 2024-09-30 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID f859c028-5a8f-460e-a43c-c0ffe20991a1 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,563,445
#       Data Scanned: 405.90 GB
#       Est. Cost: $1.9819
#
# === 2024-10-01 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 258ad924-d780-4ff9-829b-2a09c41ecf4c successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,725,497
#       Data Scanned: 402.06 GB
#       Est. Cost: $1.9632
#
# === 2024-10-02 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID e5dbfc53-f7f3-4079-8c0c-1263fa2d6f20 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,681,071
#       Data Scanned: 419.29 GB
#       Est. Cost: $2.0473
#
# === 2024-10-03 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 67011c7b-dddf-40f0-98da-6919911f860a successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,391,233
#       Data Scanned: 366.95 GB
#       Est. Cost: $1.7917
#
# === 2024-10-04 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID c9d9415c-7b7f-42ba-98a6-a2e7e6c0823c successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,583,489
#       Data Scanned: 432.64 GB
#       Est. Cost: $2.1125
#
# === 2024-10-05 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID ee66e7bc-819f-4ec8-b995-4a8959a0a10f successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,365,441
#       Data Scanned: 425.67 GB
#       Est. Cost: $2.0785
#
# === 2024-10-06 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 98cdf715-d3f5-4820-8860-e2c5dbfe3dbd successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,488,859
#       Data Scanned: 405.46 GB
#       Est. Cost: $1.9798
#
# === 2024-10-07 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID f7c3716f-c3be-4416-a106-28f05de5c9e5 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,661,134
#       Data Scanned: 411.87 GB
#       Est. Cost: $2.0111
#
# === 2024-10-08 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 77f8db29-75c5-4fc9-9807-fcf11afdb80a successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,668,274
#       Data Scanned: 427.44 GB
#       Est. Cost: $2.0871
#
# === 2024-10-09 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID ee28ef58-66dd-4dfd-b539-76819b8ef930 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,654,475
#       Data Scanned: 403.16 GB
#       Est. Cost: $1.9685
#
# === 2024-10-10 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 7dd898fe-c41c-4ee9-9a8f-382b88c2dace successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,784,416
#       Data Scanned: 383.36 GB
#       Est. Cost: $1.8719
#
# === 2024-10-11 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID c6d5c68e-c2bb-439c-bb33-de7a6cb1d41b successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,712,051
#       Data Scanned: 419.03 GB
#       Est. Cost: $2.0460
#
# === 2024-10-12 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 88931a8f-28f7-4d14-8a3e-99baf97b9c57 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,662,086
#       Data Scanned: 434.93 GB
#       Est. Cost: $2.1237
#
# === 2024-10-13 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 69682f67-d629-4a66-9926-51024cb55ebe successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,548,433
#       Data Scanned: 434.46 GB
#       Est. Cost: $2.1214
#
# === 2024-10-14 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 6dacedfb-6a1d-481f-ba96-239b188f3939 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,681,351
#       Data Scanned: 421.45 GB
#       Est. Cost: $2.0578
#
# === 2024-10-15 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 636c8522-dfd6-4aad-b199-f06e9af132f9 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,827,074
#       Data Scanned: 431.24 GB
#       Est. Cost: $2.1057
#
# === 2024-10-16 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 01d028c2-839a-4419-98ec-4ef65687f33c successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,774,936
#       Data Scanned: 415.61 GB
#       Est. Cost: $2.0293
#
# === 2024-10-17 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 68220939-93af-4dd1-aeaa-040c37c0d13d successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,834,611
#       Data Scanned: 417.30 GB
#       Est. Cost: $2.0376
#
# === 2024-10-18 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID bb3768af-4e5f-4e5b-8caf-87bf5e9189f5 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,884,230
#       Data Scanned: 418.09 GB
#       Est. Cost: $2.0415
#
# === 2024-10-19 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 5725c798-7b65-4ac1-931c-eb9c6d3bafa9 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,705,607
#       Data Scanned: 400.91 GB
#       Est. Cost: $1.9575
#
# === 2024-10-20 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID ab893e67-40a9-4d14-8479-d539471834bf successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,699,151
#       Data Scanned: 416.70 GB
#       Est. Cost: $2.0346
#
# === 2024-10-21 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 156c92b4-cc9d-478a-96a5-e30ce1252804 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,762,768
#       Data Scanned: 384.44 GB
#       Est. Cost: $1.8771
#
# === 2024-10-22 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 3a1a5917-e509-48a4-8d0f-1bc0298030a1 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,100,504
#       Data Scanned: 409.61 GB
#       Est. Cost: $2.0001
#
# === 2024-10-23 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 52e54ce6-fce0-4da2-9c91-f7c75e98c2dd successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,873,961
#       Data Scanned: 405.10 GB
#       Est. Cost: $1.9780
#
# === 2024-10-24 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 24447c7b-c5bf-48c8-bc7c-0eed5361ba53 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,628,003
#       Data Scanned: 403.53 GB
#       Est. Cost: $1.9703
#
# === 2024-10-25 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 655e0a79-a1d5-453d-8940-c1261cf5baff successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,636,679
#       Data Scanned: 411.40 GB
#       Est. Cost: $2.0088
#
# === 2024-10-26 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 9c7b6950-6389-4b59-b941-2472de60ab7f successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,430,312
#       Data Scanned: 426.85 GB
#       Est. Cost: $2.0842
#
# === 2024-10-27 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID aa2a6249-61e1-4e13-abaf-271cee3ff840 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,425,050
#       Data Scanned: 427.01 GB
#       Est. Cost: $2.0850
#
# === 2024-10-28 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 1df25855-2927-4265-999b-e88e08680ece successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,537,624
#       Data Scanned: 405.00 GB
#       Est. Cost: $1.9775
#
# === 2024-10-29 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 51e418a5-2972-4ac9-8d97-c65bfed0dc3d successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,649,634
#       Data Scanned: 380.63 GB
#       Est. Cost: $1.8585
#
# === 2024-10-30 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 97e816a2-41b3-424f-98ed-468254fccc9f successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,597,673
#       Data Scanned: 419.34 GB
#       Est. Cost: $2.0476
#
# === 2024-10-31 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 9fcdacd5-ad97-4a49-9378-c50c122b3733 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,401,884
#       Data Scanned: 439.72 GB
#       Est. Cost: $2.1471
#
# === 2024-11-01 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 4ef6b215-8995-4525-a6c8-ca78b894a3ff successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,466,709
#       Data Scanned: 450.86 GB
#       Est. Cost: $2.2015
#
# === 2024-11-02 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID da074dab-a6cd-450c-be05-a6d788e6142a successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,329,367
#       Data Scanned: 455.06 GB
#       Est. Cost: $2.2220
#
# === 2024-11-03 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 70cb2dce-1d3b-451c-a47a-131d926bcaf3 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,425,654
#       Data Scanned: 428.33 GB
#       Est. Cost: $2.0915
#
# === 2024-11-04 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID c2089484-05d4-407d-81f4-5315c25c86c3 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,404,758
#       Data Scanned: 436.86 GB
#       Est. Cost: $2.1331
#
# === 2024-11-05 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID df0f21a4-6ecb-47d1-bd60-471e849e393e successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,636,360
#       Data Scanned: 442.08 GB
#       Est. Cost: $2.1586
#
# === 2024-11-06 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 1798d6a7-33f1-479d-bf8a-d6c7380c3cc8 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,607,243
#       Data Scanned: 395.37 GB
#       Est. Cost: $1.9305
#
# === 2024-11-07 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID b739a489-79b9-4ff6-90ba-4e46b202f55a successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,427,193
#       Data Scanned: 414.73 GB
#       Est. Cost: $2.0251
#
# === 2024-11-08 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 0f1c02e4-d0a1-4640-8cd0-1496e398b3ac successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,518,659
#       Data Scanned: 427.26 GB
#       Est. Cost: $2.0862
#
# === 2024-11-09 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 49761f45-c381-45a2-afaf-24b66c0c955c successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,333,393
#       Data Scanned: 462.17 GB
#       Est. Cost: $2.2567
#
# === 2024-11-10 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 52c8016e-4ed9-4006-b334-2e055ef1cfe2 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,400,090
#       Data Scanned: 517.34 GB
#       Est. Cost: $2.5261
#
# === 2024-11-11 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 85195de6-de87-46cf-9a6d-f8cea14a5a4c successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,715,215
#       Data Scanned: 486.66 GB
#       Est. Cost: $2.3763
#
# === 2024-11-12 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID a547478e-f599-4b5f-9c45-028766cec07f successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,951,437
#       Data Scanned: 497.66 GB
#       Est. Cost: $2.4300
#
# === 2024-11-13 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 3f59f9c0-58fc-45de-ae3c-393ddfd4159d successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,802,951
#       Data Scanned: 492.95 GB
#       Est. Cost: $2.4070
#
# === 2024-11-14 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID e632283a-6caa-46c1-9fce-eb10394b8756 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,061,197
#       Data Scanned: 489.82 GB
#       Est. Cost: $2.3917
#
# === 2024-11-15 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID ad925123-b1ba-431b-b625-7a2ce38f4a21 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,968,983
#       Data Scanned: 496.59 GB
#       Est. Cost: $2.4248
#
# === 2024-11-16 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID cbbe086d-673f-4b80-a23c-ff9fe3ac28d1 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,276,875
#       Data Scanned: 521.27 GB
#       Est. Cost: $2.5453
#
# === 2024-11-17 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID ad886c55-2a7a-437f-8788-72a55fad27bd successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,193,901
#       Data Scanned: 505.62 GB
#       Est. Cost: $2.4689
#
# === 2024-11-18 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 8d94007b-2c45-4f62-89c9-584e26add217 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,322,933
#       Data Scanned: 513.78 GB
#       Est. Cost: $2.5087
#
# === 2024-11-19 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID e5d6631e-cbd6-4ce2-b6b6-3c621c756f18 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,472,107
#       Data Scanned: 517.21 GB
#       Est. Cost: $2.5254
#
# === 2024-11-20 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 9650afb4-c7c2-4765-8b94-c17e53a1da8b successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,497,863
#       Data Scanned: 525.70 GB
#       Est. Cost: $2.5669
#
# === 2024-11-21 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID aa69fdd7-0079-4c10-a618-15bf04ff4672 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,532,809
#       Data Scanned: 538.62 GB
#       Est. Cost: $2.6300
#
# === 2024-11-22 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID cd187d5c-592b-4baa-b40f-a9e15262822d successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,469,616
#       Data Scanned: 548.69 GB
#       Est. Cost: $2.6791
#
# === 2024-11-23 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 26ed8ac5-65ce-4171-bb88-7d48a1315c93 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,247,520
#       Data Scanned: 553.09 GB
#       Est. Cost: $2.7006
#
# === 2024-11-24 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 93930811-84d0-4e0a-9d7f-784957de89ce successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,201,559
#       Data Scanned: 574.43 GB
#       Est. Cost: $2.8048
#
# === 2024-11-25 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID a82ed228-3062-471e-b9b8-4b74f89281bd successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,318,957
#       Data Scanned: 581.06 GB
#       Est. Cost: $2.8372
#
# === 2024-11-26 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID f397853d-ed4c-4aca-bcaf-5e793354ee5a successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,208,812
#       Data Scanned: 580.07 GB
#       Est. Cost: $2.8324
#
# === 2024-11-27 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 4a8de1db-be70-4b52-898a-71584468f765 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,325,126
#       Data Scanned: 571.42 GB
#       Est. Cost: $2.7902
#
# === 2024-11-28 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 00fa00ab-9a1b-4cba-a4c8-9bb4684ce159 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,200,142
#       Data Scanned: 583.73 GB
#       Est. Cost: $2.8502
#
# === 2024-11-29 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 4176cb7d-78d1-417e-8c01-80e33be2eff4 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,973,772
#       Data Scanned: 600.52 GB
#       Est. Cost: $2.9322
#
# === 2024-11-30 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 67bbc7b6-8802-428f-9534-18d12b3158e0 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,780,878
#       Data Scanned: 620.95 GB
#       Est. Cost: $3.0320
#
# === 2024-12-01 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 5f2bd150-06fa-44ca-b72f-04ce8d0ff337 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,731,082
#       Data Scanned: 612.93 GB
#       Est. Cost: $2.9928
#
# === 2024-12-02 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 09aa222e-6aa7-4120-b827-3128e5f1dd66 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,924,474
#       Data Scanned: 601.54 GB
#       Est. Cost: $2.9372
#
# === 2024-12-03 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 899db1e7-479e-4b30-a336-a3af9ec9d44f successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,887,764
#       Data Scanned: 611.53 GB
#       Est. Cost: $2.9860
#
# === 2024-12-04 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID ad4f2d38-7475-4a4c-8352-6a6eb4ae0e4b successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,687,415
#       Data Scanned: 615.38 GB
#       Est. Cost: $3.0048
#
# === 2024-12-05 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID d185dc8c-bf86-4d09-a853-5de37d9ba24f successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,858,432
#       Data Scanned: 613.72 GB
#       Est. Cost: $2.9967
#
# === 2024-12-06 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 26dc7f04-c3d1-4790-8217-42ea11de8bfc successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,867,593
#       Data Scanned: 623.71 GB
#       Est. Cost: $3.0454
#
# === 2024-12-07 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 267c61f6-bd86-4c6f-b9e6-8134af3d7cb8 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,773,028
#       Data Scanned: 628.08 GB
#       Est. Cost: $3.0668
#
# === 2024-12-08 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 9bc677a9-e6f1-4b97-946a-47f4f93d7c7a successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,649,787
#       Data Scanned: 612.12 GB
#       Est. Cost: $2.9889
#
# === 2024-12-09 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 7b051b08-0b34-4622-bd94-bf8124a8a2da successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,816,180
#       Data Scanned: 618.97 GB
#       Est. Cost: $3.0223
#
# === 2024-12-10 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 46147640-41b2-45b9-9189-ce6aed155a70 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,975,271
#       Data Scanned: 605.92 GB
#       Est. Cost: $2.9586
#
# === 2024-12-11 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID b80876e6-14b5-4b76-8ae8-1501e91869f0 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 2,101,708
#       Data Scanned: 645.94 GB
#       Est. Cost: $3.1540
#
# === 2024-12-12 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 467d1f60-f182-4133-a389-381aad44e6cf successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,994,440
#       Data Scanned: 654.14 GB
#       Est. Cost: $3.1940
#
# === 2024-12-13 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID b4922175-9ffa-4e3e-ad3a-315385cbd016 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,975,918
#       Data Scanned: 646.06 GB
#       Est. Cost: $3.1546
#
# === 2024-12-14 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID f8fb2e12-3ba3-4fc6-8362-632f5bd930a2 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,907,621
#       Data Scanned: 650.76 GB
#       Est. Cost: $3.1775
#
# === 2024-12-15 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID d49f198c-22b9-4159-8b52-cdb684e36fa6 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,749,236
#       Data Scanned: 651.38 GB
#       Est. Cost: $3.1806
#
# === 2024-12-16 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID dbda6b3c-461d-4e18-ae29-59836f0353b2 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 1,998,038
#       Data Scanned: 653.62 GB
#       Est. Cost: $3.1915
#
# === 2024-12-17 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 01db1412-451a-4f81-807b-4e3a16c4fa1c successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
#       Rows: 3,047,895
#       Data Scanned: 637.41 GB
#       Est. Cost: $3.1123
#
# === 2024-12-18 ===
#   [1/2] Engineering Cascade features...
#   [2/2] Exporting to feather...
# Job ID 7a6361db-3b4b-40ca-90c0-bf6d1b76de81 successfully executed: 100%|████████████████████████████████████████████████████████████████████|
# Downloading: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████|
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[67], line 26
#      24 if not df.empty:
#      25     df = downcast_df(df)
# ---> 26     df.to_feather(out_path)
#      27 bytes_billed = (job1.total_bytes_billed or 0) + (job2.total_bytes_billed or 0)
#      28 total_gb = bytes_billed / (1024**3)
#
# File /opt/pytorch/lib/python3.13/site-packages/pandas/core/frame.py:2949, in DataFrame.to_feather(self, path, **kwargs)
#    2921 """
#    2922 Write a DataFrame to the binary Feather format.
#    2923
#    (...)   2945 >>> df.to_feather("file.feather")  # doctest: +SKIP
#    2946 """
#    2947 from pandas.io.feather_format import to_feather
# -> 2949 to_feather(self, path, **kwargs)
#
# File /opt/pytorch/lib/python3.13/site-packages/pandas/io/feather_format.py:65, in to_feather(df, path, storage_options, **kwargs)
#      60     raise ValueError("feather only support IO with DataFrames")
#      62 with get_handle(
#      63     path, "wb", storage_options=storage_options, is_text=False
#      64 ) as handles:
# ---> 65     feather.write_feather(df, handles.handle, **kwargs)
#
# File /opt/pytorch/lib/python3.13/site-packages/pyarrow/feather.py:186, in write_feather(df, dest, compression, compression_level, chunksize, version)
#     182         raise ValueError(f'compression="{compression}" not supported, must be '
#     183                          f'one of {_FEATHER_SUPPORTED_CODECS}')
#     185 try:
# --> 186     _feather.write_feather(table, dest, compression=compression,
#     187                            compression_level=compression_level,
#     188                            chunksize=chunksize, version=version)
#     189 except Exception:
#     190     if isinstance(dest, str):
#
# File /opt/pytorch/lib/python3.13/site-packages/pyarrow/_feather.pyx:63, in pyarrow._feather.write_feather()
#
# File /opt/pytorch/lib/python3.13/site-packages/pyarrow/error.pxi:89, in pyarrow.lib.check_status()
#
# OSError: [Errno 28] No space left on device
